# %% [markdown]
# # Gesture Recognition
#
# In this project, we are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.
#
# Problem Statement
# Imagine we are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. We want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
# The gestures are continuously monitored by the webcam mounted on the TV. Each gesture corresponds to a specific command:
#
# - Thumbs up:  Increase the volume
# - Thumbs down: Decrease the volume
# - Left swipe: 'Jump' backwards 10 seconds
# - Right swipe: 'Jump' forward 10 seconds
# - Stop: Pause the movie
#
#
# Each video is a sequence of 30 frames (or images).

# %%
import numpy as np
import os
import imageio
from skimage.transform import resize, rescale
import datetime
import os

import matplotlib.pyplot as plt

from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
import tensorflow as tf
print(tf.__version__)
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
tf.random.set_seed(30)
# Out:
# 2.16.1

# %%
project_folder = "Project_data"

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
num_classes = 5  #number of softmax classes

# %%
curr_dt_time = datetime.datetime.now()
train_path = project_folder + '/' + 'train'
val_path = project_folder + '/' + 'val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
# Out:
# # training sequences = 663
# # validation sequences = 100

# %% [markdown]
# ## Common Utils

# %% [markdown]
# Common utility to plot loss and accuracy

# %%
def plot_loss_accuracy(history):
    # list all data in history
    print(history.history.keys())
    # summarize history for accuracy
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %% [markdown]
# Common utility to calculate steps

# %%
def calculate_steps(num_train_sequences, num_val_sequences, batch_size):
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    return steps_per_epoch,validation_steps

# %% [markdown]
# Common utility for callbacks

# %%
def model_callbacks(folder_name):
    model_name = str(folder_name) + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
   
    if not os.path.exists(model_name):
        os.mkdir(model_name)

    filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.keras'

    checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto')

    LR = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, min_lr=0.0001, cooldown=1, verbose=1) # write the REducelronplateau code here

    return [checkpoint, LR]

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, we are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. we have to experiment with `img_idx`, `y`,`z` and normalization such that we get high accuracy.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from keras.preprocessing.image import smart_resize

datagen = ImageDataGenerator(
    zoom_range=0.1,
    zca_whitening=True,
    width_shift_range=0.1,
    height_shift_range=0.1)

## Test code start
#360 by 360
# image1 = imageio.imread("/kaggle/input/gesture-recognition/train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00012.png")
image1 = imageio.imread(project_folder + '/' + 'train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00012.png')
#160 by 120
# image2 = imageio.imread("/kaggle/input/gesture-recognition/val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png")
image2 = imageio.imread(project_folder + '/' + 'val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png')
#crop the images and resize them. Note that the images are of 2 different shape 
#and the conv3D will throw error if the inputs in a batch have different shapes                    
#print(image1.shape, image2.shape)
image1 = resize(image1, (120, 120), anti_aliasing=True)
image1 = datagen.random_transform(image1)                   
plt.imshow(image1)
plt.show()
image2 = resize(image2, (120, 120), anti_aliasing=True)
image2 = datagen.random_transform(image2)                 
plt.imshow(image2)
plt.show()
## Test code end

def generate(source_path, folder_list, batch_size, num_images=20, height=120, width=120, augment=False):
    #print( 'Source path = ', source_path, '; batch size =', batch_size)
    total_frames = 30

    while True:
        t = np.random.permutation(folder_list)
        num_batches = len(t)//batch_size # calculate the number of batches
        #img_idx = sorted(rn.sample(range(0, total_frames), num_images)) #create a list of image numbers you want to use for a particular video
        img_idx = np.round(np.linspace(0,total_frames-1,num_images)).astype(int) #create a list of image numbers you want to use for a particular video

        for batch in range(num_batches): # we iterate over the number of batches
            batch_data   = np.zeros((batch_size, num_images, height, width, 3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size, 5)) # batch_labels is the one hot representation of the output           

            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes                    
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)

                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image                  
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        if (len(t)%batch_size):
            remaining_batch_size = len(t)%batch_size
            batch_data   = np.zeros((remaining_batch_size, num_images, height, width,3)) # 3 is the number of channels RGB
            batch_labels = np.zeros((remaining_batch_size,5)) # batch_labels is the one hot representation of the output           

            for folder in range(remaining_batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    h, w, c = image.shape
                    image = resize(image, (height, width), anti_aliasing=True)                          
                    
                    # Randomly transform few images of few folders; note that folders are randomly shuffled in each epoch too
                    if augment:
                        if np.random.randn() > 0:
                            image = datagen.random_transform(image)                   

                    batch_data[folder,idx,:,:,0] = (image[...,0])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = (image[...,1])/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = (image[...,2])/255 #normalise and feed in the image
                   
                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/legacy/preprocessing/image.py:1047: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn(
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2963303598.py:13: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image1 = imageio.imread(project_folder + '/' + 'train/WIN_20180907_15_35_09_Pro_Right Swipe_new/WIN_20180907_15_35_09_Pro_00012.png')
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2963303598.py:16: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image2 = imageio.imread(project_folder + '/' + 'val/WIN_20180907_15_30_06_Pro_Right Swipe_new/WIN_20180907_15_30_06_Pro_00015.png')

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# ## Model
# Here we make the model using different functionalities that Keras provides. We will use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. We would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. We will Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, GRU, LSTM, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.regularizers import l2
from keras import optimizers

# %% [markdown]
# ### Conv3d Models

# %%
# Common utility to create conv 3D models
def conv3D(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (3, 3, 3), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %% [markdown]
# #### Model 1: Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 30
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 2024-04-01 00:02:11.090396: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-04-01 00:02:11.090412: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-04-01 00:02:11.090417: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-04-01 00:02:11.090432: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-01 00:02:11.090440: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d (Conv3D)                 │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 120, 120,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d (MaxPooling3D)    │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_1 (Conv3D)               │ (None, 15, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 15, 60, 60, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 60, 60, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_1 (MaxPooling3D)  │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_2 (Conv3D)               │ (None, 7, 30, 30, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 7, 30, 30, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 7, 30, 30, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_2 (MaxPooling3D)  │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_3 (Conv3D)               │ (None, 3, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 3, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 3, 15, 15, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_3 (MaxPooling3D)  │ (None, 1, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_6 (Activation)       │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,933,765 (7.38 MB)
#  Trainable params: 1,932,517 (7.37 MB)
#  Non-trainable params: 1,248 (4.88 KB)
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_1")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                             callbacks=callbacks_list, validation_data=val_generator, 
                             validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 2024-04-01 00:02:14.594588: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.3038 - loss: 2.0533
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3070 - loss: 2.0432
# Epoch 1: val_loss improved from inf to 6.72364, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00001-1.70684-0.41327-6.72364-0.26000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 195s 3s/step - categorical_accuracy: 0.3086 - loss: 2.0382 - val_categorical_accuracy: 0.2600 - val_loss: 6.7236 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5354 - loss: 1.3827
# Epoch 2: val_loss improved from 6.72364 to 3.54072, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00002-1.32626-0.53243-3.54072-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 190s 3s/step - categorical_accuracy: 0.5353 - loss: 1.3819 - val_categorical_accuracy: 0.3200 - val_loss: 3.5407 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6473 - loss: 0.9706
# Epoch 3: val_loss improved from 3.54072 to 3.34287, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00003-1.03578-0.61538-3.34287-0.40000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - categorical_accuracy: 0.6469 - loss: 0.9715 - val_categorical_accuracy: 0.4000 - val_loss: 3.3429 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6443 - loss: 0.8509
# Epoch 4: val_loss improved from 3.34287 to 2.82044, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00004-0.87335-0.65309-2.82044-0.32000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.6444 - loss: 0.8512 - val_categorical_accuracy: 0.3200 - val_loss: 2.8204 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6681 - loss: 0.9286
# Epoch 5: val_loss improved from 2.82044 to 1.84538, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00005-0.96785-0.64857-1.84538-0.46000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.6678 - loss: 0.9291 - val_categorical_accuracy: 0.4600 - val_loss: 1.8454 - learning_rate: 0.0010
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7308 - loss: 0.7145
# Epoch 6: val_loss improved from 1.84538 to 1.67761, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00006-0.73576-0.72247-1.67761-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.7307 - loss: 0.7148 - val_categorical_accuracy: 0.5100 - val_loss: 1.6776 - learning_rate: 0.0010
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7372 - loss: 0.6314
# Epoch 7: val_loss did not improve from 1.67761
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.7368 - loss: 0.6321 - val_categorical_accuracy: 0.5300 - val_loss: 1.8441 - learning_rate: 0.0010
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7997 - loss: 0.5293
# Epoch 8: val_loss improved from 1.67761 to 1.41478, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00008-0.57080-0.79035-1.41478-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.7995 - loss: 0.5299 - val_categorical_accuracy: 0.5700 - val_loss: 1.4148 - learning_rate: 0.0010
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8097 - loss: 0.5321
# Epoch 9: val_loss did not improve from 1.41478
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.8097 - loss: 0.5316 - val_categorical_accuracy: 0.5600 - val_loss: 1.5468 - learning_rate: 0.0010
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8318 - loss: 0.4588
# Epoch 10: val_loss improved from 1.41478 to 1.35224, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00010-0.52805-0.80845-1.35224-0.61000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.8315 - loss: 0.4599 - val_categorical_accuracy: 0.6100 - val_loss: 1.3522 - learning_rate: 0.0010
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8127 - loss: 0.5384
# Epoch 11: val_loss did not improve from 1.35224
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.8124 - loss: 0.5392 - val_categorical_accuracy: 0.3900 - val_loss: 2.4214 - learning_rate: 0.0010
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7576 - loss: 0.6178
# Epoch 12: val_loss improved from 1.35224 to 1.19959, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00012-0.60239-0.77376-1.19959-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.7579 - loss: 0.6176 - val_categorical_accuracy: 0.6300 - val_loss: 1.1996 - learning_rate: 0.0010
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8308 - loss: 0.4688
# Epoch 13: val_loss did not improve from 1.19959
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.8308 - loss: 0.4684 - val_categorical_accuracy: 0.3700 - val_loss: 7.4749 - learning_rate: 0.0010
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8543 - loss: 0.3577
# Epoch 14: val_loss did not improve from 1.19959
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 182s 3s/step - categorical_accuracy: 0.8544 - loss: 0.3584 - val_categorical_accuracy: 0.4900 - val_loss: 2.8704 - learning_rate: 0.0010
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8372 - loss: 0.4123
# Epoch 15: val_loss did not improve from 1.19959
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.8372 - loss: 0.4130 - val_categorical_accuracy: 0.5700 - val_loss: 1.8721 - learning_rate: 0.0010
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8708 - loss: 0.3239
# Epoch 16: val_loss improved from 1.19959 to 1.06355, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00016-0.33308-0.88084-1.06355-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.8709 - loss: 0.3240 - val_categorical_accuracy: 0.6600 - val_loss: 1.0636 - learning_rate: 1.0000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9040 - loss: 0.2701
# Epoch 17: val_loss improved from 1.06355 to 0.84960, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00017-0.28241-0.90196-0.84960-0.71000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 183s 3s/step - categorical_accuracy: 0.9040 - loss: 0.2703 - val_categorical_accuracy: 0.7100 - val_loss: 0.8496 - learning_rate: 1.0000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9206 - loss: 0.2261
# Epoch 18: val_loss improved from 0.84960 to 0.84958, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00018-0.20144-0.93514-0.84958-0.71000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.9208 - loss: 0.2257 - val_categorical_accuracy: 0.7100 - val_loss: 0.8496 - learning_rate: 1.0000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9041 - loss: 0.2450
# Epoch 19: val_loss did not improve from 0.84958
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.9044 - loss: 0.2448 - val_categorical_accuracy: 0.7100 - val_loss: 0.8779 - learning_rate: 1.0000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9474 - loss: 0.1768
# Epoch 20: val_loss improved from 0.84958 to 0.83208, saving model to model_conv3D_1_2024-04-0100_02_10.957255/model-00020-0.21902-0.92911-0.83208-0.71000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 184s 3s/step - categorical_accuracy: 0.9471 - loss: 0.1774 - val_categorical_accuracy: 0.7100 - val_loss: 0.8321 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Model 2: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 20 # choose the number of epochs
#print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_4 (Conv3D)               │ (None, 20, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_7 (Activation)       │ (None, 20, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 20, 120, 120,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_4 (MaxPooling3D)  │ (None, 10, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_5 (Conv3D)               │ (None, 10, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_8 (Activation)       │ (None, 10, 60, 60, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 10, 60, 60, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_5 (MaxPooling3D)  │ (None, 5, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_6 (Conv3D)               │ (None, 5, 30, 30, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_9 (Activation)       │ (None, 5, 30, 30, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 5, 30, 30, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_6 (MaxPooling3D)  │ (None, 2, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_7 (Conv3D)               │ (None, 2, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_10 (Activation)      │ (None, 2, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 2, 15, 15, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_7 (MaxPooling3D)  │ (None, 1, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_11 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_12 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_13 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,933,765 (7.38 MB)
#  Trainable params: 1,932,517 (7.37 MB)
#  Non-trainable params: 1,248 (4.88 KB)
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_2")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 3s 2s/step - categorical_accuracy: 0.3806 - loss: 1.7745
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3824 - loss: 1.7694
# Epoch 1: val_loss improved from inf to 1.85274, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00001-1.60359-0.43891-1.85274-0.17000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 137s 2s/step - categorical_accuracy: 0.3832 - loss: 1.7669 - val_categorical_accuracy: 0.1700 - val_loss: 1.8527 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5306 - loss: 1.1845
# Epoch 2: val_loss did not improve from 1.85274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 129s 2s/step - categorical_accuracy: 0.5311 - loss: 1.1832 - val_categorical_accuracy: 0.3100 - val_loss: 2.9712 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6277 - loss: 1.0005
# Epoch 3: val_loss did not improve from 1.85274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 127s 2s/step - categorical_accuracy: 0.6276 - loss: 1.0009 - val_categorical_accuracy: 0.3200 - val_loss: 2.1508 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7259 - loss: 0.7290
# Epoch 4: val_loss did not improve from 1.85274
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.7257 - loss: 0.7307 - val_categorical_accuracy: 0.2700 - val_loss: 2.2703 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7409 - loss: 0.6728
# Epoch 5: val_loss did not improve from 1.85274
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.7409 - loss: 0.6737 - val_categorical_accuracy: 0.4700 - val_loss: 1.8628 - learning_rate: 1.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7876 - loss: 0.5923
# Epoch 6: val_loss improved from 1.85274 to 1.56857, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00006-0.58640-0.77677-1.56857-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.7874 - loss: 0.5922 - val_categorical_accuracy: 0.5000 - val_loss: 1.5686 - learning_rate: 1.0000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8152 - loss: 0.5401
# Epoch 7: val_loss improved from 1.56857 to 1.24375, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00007-0.56984-0.79940-1.24375-0.58000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.8150 - loss: 0.5406 - val_categorical_accuracy: 0.5800 - val_loss: 1.2437 - learning_rate: 1.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7712 - loss: 0.5558
# Epoch 8: val_loss improved from 1.24375 to 1.09863, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00008-0.53507-0.78582-1.09863-0.63000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.7714 - loss: 0.5555 - val_categorical_accuracy: 0.6300 - val_loss: 1.0986 - learning_rate: 1.0000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8014 - loss: 0.4854
# Epoch 9: val_loss improved from 1.09863 to 0.98975, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00009-0.46055-0.82504-0.98975-0.62000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8018 - loss: 0.4851 - val_categorical_accuracy: 0.6200 - val_loss: 0.9898 - learning_rate: 1.0000e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8499 - loss: 0.4534
# Epoch 10: val_loss improved from 0.98975 to 0.86199, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00010-0.48704-0.82353-0.86199-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8495 - loss: 0.4539 - val_categorical_accuracy: 0.6700 - val_loss: 0.8620 - learning_rate: 1.0000e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8648 - loss: 0.3950
# Epoch 11: val_loss improved from 0.86199 to 0.79487, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00011-0.39954-0.85219-0.79487-0.71000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8646 - loss: 0.3951 - val_categorical_accuracy: 0.7100 - val_loss: 0.7949 - learning_rate: 1.0000e-04
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8512 - loss: 0.4065
# Epoch 12: val_loss did not improve from 0.79487
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8514 - loss: 0.4063 - val_categorical_accuracy: 0.7300 - val_loss: 0.7956 - learning_rate: 1.0000e-04
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8880 - loss: 0.3304
# Epoch 13: val_loss improved from 0.79487 to 0.73542, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00013-0.36783-0.87179-0.73542-0.75000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8878 - loss: 0.3310 - val_categorical_accuracy: 0.7500 - val_loss: 0.7354 - learning_rate: 1.0000e-04
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8553 - loss: 0.3870
# Epoch 14: val_loss improved from 0.73542 to 0.68510, saving model to model_conv3D_2_2024-04-0100_02_10.957255/model-00014-0.36705-0.87632-0.68510-0.76000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.8556 - loss: 0.3867 - val_categorical_accuracy: 0.7600 - val_loss: 0.6851 - learning_rate: 1.0000e-04
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8887 - loss: 0.3039
# Epoch 15: val_loss did not improve from 0.68510
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.8888 - loss: 0.3038 - val_categorical_accuracy: 0.7600 - val_loss: 0.7318 - learning_rate: 1.0000e-04
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8903 - loss: 0.2971
# Epoch 16: val_loss did not improve from 0.68510
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.8904 - loss: 0.2970 - val_categorical_accuracy: 0.7500 - val_loss: 0.7844 - learning_rate: 1.0000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9139 - loss: 0.2906
# Epoch 17: val_loss did not improve from 0.68510
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.9138 - loss: 0.2911 - val_categorical_accuracy: 0.7300 - val_loss: 0.7619 - learning_rate: 1.0000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9183 - loss: 0.2627
# Epoch 18: val_loss did not improve from 0.68510
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.9183 - loss: 0.2629 - val_categorical_accuracy: 0.7400 - val_loss: 0.7526 - learning_rate: 1.0000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9545 - loss: 0.2014
# Epoch 19: val_loss did not improve from 0.68510
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.9540 - loss: 0.2021 - val_categorical_accuracy: 0.6900 - val_loss: 0.7806 - learning_rate: 1.0000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9216 - loss: 0.2365
# Epoch 20: val_loss did not improve from 0.68510
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 124s 2s/step - categorical_accuracy: 0.9216 - loss: 0.2366 - val_categorical_accuracy: 0.7500 - val_loss: 0.7247 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# #### Model 3: Conv 3D Model with 20 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 160 by 160)

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 160
width = 160

model = conv3D(num_images=num_frames, height=160, width=160)

print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num_frames per video = 20
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_8 (Conv3D)               │ (None, 20, 160, 160,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_14 (Activation)      │ (None, 20, 160, 160,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 20, 160, 160,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_8 (MaxPooling3D)  │ (None, 10, 80, 80, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_9 (Conv3D)               │ (None, 10, 80, 80, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_15 (Activation)      │ (None, 10, 80, 80, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 10, 80, 80, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_9 (MaxPooling3D)  │ (None, 5, 40, 40, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_10 (Conv3D)              │ (None, 5, 40, 40, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_16 (Activation)      │ (None, 5, 40, 40, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 5, 40, 40, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_10 (MaxPooling3D) │ (None, 2, 20, 20, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_11 (Conv3D)              │ (None, 2, 20, 20, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_17 (Activation)      │ (None, 2, 20, 20, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 2, 20, 20, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_11 (MaxPooling3D) │ (None, 1, 10, 10, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │     3,277,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_18 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_16          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_19 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_17          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_20 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,604,933 (13.75 MB)
#  Trainable params: 3,603,685 (13.75 MB)
#  Non-trainable params: 1,248 (4.88 KB)
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_3")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames, height=160, width=160)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames, height=160, width=160)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 6s 3s/step - categorical_accuracy: 0.3934 - loss: 1.7564
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3955 - loss: 1.7489
# Epoch 1: val_loss improved from inf to 2.02446, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00001-1.50591-0.46305-2.02446-0.25000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 241s 4s/step - categorical_accuracy: 0.3965 - loss: 1.7453 - val_categorical_accuracy: 0.2500 - val_loss: 2.0245 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5772 - loss: 1.1081
# Epoch 2: val_loss did not improve from 2.02446
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 237s 4s/step - categorical_accuracy: 0.5775 - loss: 1.1074 - val_categorical_accuracy: 0.2800 - val_loss: 2.9417 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7058 - loss: 0.7798
# Epoch 3: val_loss did not improve from 2.02446
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 235s 4s/step - categorical_accuracy: 0.7053 - loss: 0.7807 - val_categorical_accuracy: 0.2700 - val_loss: 3.7721 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6998 - loss: 0.7999
# Epoch 4: val_loss did not improve from 2.02446
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 232s 3s/step - categorical_accuracy: 0.7001 - loss: 0.7993 - val_categorical_accuracy: 0.2700 - val_loss: 6.7960 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7560 - loss: 0.6287
# Epoch 5: val_loss did not improve from 2.02446
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 230s 3s/step - categorical_accuracy: 0.7563 - loss: 0.6286 - val_categorical_accuracy: 0.2800 - val_loss: 4.9846 - learning_rate: 1.0000e-04
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8019 - loss: 0.5396
# Epoch 6: val_loss did not improve from 2.02446
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 230s 3s/step - categorical_accuracy: 0.8015 - loss: 0.5402 - val_categorical_accuracy: 0.3200 - val_loss: 3.6367 - learning_rate: 1.0000e-04
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8291 - loss: 0.5025
# Epoch 7: val_loss did not improve from 2.02446
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 224s 3s/step - categorical_accuracy: 0.8291 - loss: 0.5029 - val_categorical_accuracy: 0.3700 - val_loss: 2.1794 - learning_rate: 1.0000e-04
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8525 - loss: 0.4023
# Epoch 8: val_loss improved from 2.02446 to 1.19827, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00008-0.41468-0.85219-1.19827-0.59000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 225s 3s/step - categorical_accuracy: 0.8525 - loss: 0.4025 - val_categorical_accuracy: 0.5900 - val_loss: 1.1983 - learning_rate: 1.0000e-04
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8270 - loss: 0.4405
# Epoch 9: val_loss improved from 1.19827 to 0.99201, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00009-0.45581-0.83107-0.99201-0.61000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 226s 3s/step - categorical_accuracy: 0.8271 - loss: 0.4407 - val_categorical_accuracy: 0.6100 - val_loss: 0.9920 - learning_rate: 1.0000e-04
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8557 - loss: 0.4103
# Epoch 10: val_loss improved from 0.99201 to 0.84394, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00010-0.39413-0.86425-0.84394-0.66000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 230s 3s/step - categorical_accuracy: 0.8558 - loss: 0.4101 - val_categorical_accuracy: 0.6600 - val_loss: 0.8439 - learning_rate: 1.0000e-04
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8709 - loss: 0.3932
# Epoch 11: val_loss improved from 0.84394 to 0.73417, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00011-0.39396-0.86576-0.73417-0.74000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 227s 3s/step - categorical_accuracy: 0.8708 - loss: 0.3932 - val_categorical_accuracy: 0.7400 - val_loss: 0.7342 - learning_rate: 1.0000e-04
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8487 - loss: 0.3951
# Epoch 12: val_loss improved from 0.73417 to 0.70015, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00012-0.34368-0.87029-0.70015-0.78000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 227s 3s/step - categorical_accuracy: 0.8490 - loss: 0.3943 - val_categorical_accuracy: 0.7800 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8953 - loss: 0.2987
# Epoch 13: val_loss improved from 0.70015 to 0.67754, saving model to model_conv3D_3_2024-04-0100_02_10.957255/model-00013-0.30194-0.89140-0.67754-0.76000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 225s 3s/step - categorical_accuracy: 0.8952 - loss: 0.2988 - val_categorical_accuracy: 0.7600 - val_loss: 0.6775 - learning_rate: 1.0000e-04
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8805 - loss: 0.3305
# Epoch 14: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - categorical_accuracy: 0.8807 - loss: 0.3300 - val_categorical_accuracy: 0.7500 - val_loss: 0.7427 - learning_rate: 1.0000e-04
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8990 - loss: 0.2885
# Epoch 15: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 222s 3s/step - categorical_accuracy: 0.8988 - loss: 0.2897 - val_categorical_accuracy: 0.7300 - val_loss: 0.7675 - learning_rate: 1.0000e-04
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9290 - loss: 0.2341
# Epoch 16: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 221s 3s/step - categorical_accuracy: 0.9289 - loss: 0.2342 - val_categorical_accuracy: 0.7800 - val_loss: 0.7009 - learning_rate: 1.0000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9255 - loss: 0.2275
# Epoch 17: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 224s 3s/step - categorical_accuracy: 0.9255 - loss: 0.2278 - val_categorical_accuracy: 0.7000 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9178 - loss: 0.2366
# Epoch 18: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 225s 3s/step - categorical_accuracy: 0.9175 - loss: 0.2374 - val_categorical_accuracy: 0.7200 - val_loss: 0.7113 - learning_rate: 1.0000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9285 - loss: 0.2226
# Epoch 19: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 223s 3s/step - categorical_accuracy: 0.9286 - loss: 0.2224 - val_categorical_accuracy: 0.7500 - val_loss: 0.7199 - learning_rate: 1.0000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.9586 - loss: 0.1524
# Epoch 20: val_loss did not improve from 0.67754
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 225s 3s/step - categorical_accuracy: 0.9583 - loss: 0.1530 - val_categorical_accuracy: 0.7400 - val_loss: 0.7172 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Conv 3D Model with 30 frames per video (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer) + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_12 (Conv3D)              │ (None, 30, 120, 120,   │         1,312 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_21 (Activation)      │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_18          │ (None, 30, 120, 120,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_12 (MaxPooling3D) │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_13 (Conv3D)              │ (None, 15, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_22 (Activation)      │ (None, 15, 60, 60, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 15, 60, 60, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_13 (MaxPooling3D) │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_14 (Conv3D)              │ (None, 7, 30, 30, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_23 (Activation)      │ (None, 7, 30, 30, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 7, 30, 30, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_14 (MaxPooling3D) │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_15 (Conv3D)              │ (None, 3, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_24 (Activation)      │ (None, 3, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 3, 15, 15, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_15 (MaxPooling3D) │ (None, 1, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_25 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_26 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_27 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,933,765 (7.38 MB)
#  Trainable params: 1,932,517 (7.37 MB)
#  Non-trainable params: 1,248 (4.88 KB)
# None

# %%
callbacks_list = model_callbacks("model_conv3D_4")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.3810 - loss: 1.7750
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3821 - loss: 1.7713
# Epoch 1: val_loss improved from inf to 2.07958, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00001-1.64449-0.42081-2.07958-0.24000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 198s 3s/step - categorical_accuracy: 0.3827 - loss: 1.7695 - val_categorical_accuracy: 0.2400 - val_loss: 2.0796 - learning_rate: 0.0010
# Epoch 2/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5785 - loss: 1.1998
# Epoch 2: val_loss did not improve from 2.07958
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - categorical_accuracy: 0.5783 - loss: 1.1994 - val_categorical_accuracy: 0.2200 - val_loss: 2.2879 - learning_rate: 0.0010
# Epoch 3/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6156 - loss: 1.0521
# Epoch 3: val_loss improved from 2.07958 to 2.00549, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00003-1.10519-0.58371-2.00549-0.33000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 190s 3s/step - categorical_accuracy: 0.6151 - loss: 1.0528 - val_categorical_accuracy: 0.3300 - val_loss: 2.0055 - learning_rate: 0.0010
# Epoch 4/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6279 - loss: 0.9555
# Epoch 4: val_loss did not improve from 2.00549
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.6279 - loss: 0.9555 - val_categorical_accuracy: 0.3600 - val_loss: 2.2851 - learning_rate: 0.0010
# Epoch 5/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6548 - loss: 0.8455
# Epoch 5: val_loss improved from 2.00549 to 1.34511, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00005-0.90717-0.62896-1.34511-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.6544 - loss: 0.8464 - val_categorical_accuracy: 0.5100 - val_loss: 1.3451 - learning_rate: 0.0010
# Epoch 6/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7276 - loss: 0.6702
# Epoch 6: val_loss did not improve from 1.34511
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 193s 3s/step - categorical_accuracy: 0.7271 - loss: 0.6720 - val_categorical_accuracy: 0.4100 - val_loss: 2.9630 - learning_rate: 0.0010
# Epoch 7/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6799 - loss: 0.8758
# Epoch 7: val_loss did not improve from 1.34511
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.6794 - loss: 0.8768 - val_categorical_accuracy: 0.4600 - val_loss: 1.9714 - learning_rate: 0.0010
# Epoch 8/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6914 - loss: 0.8904
# Epoch 8: val_loss did not improve from 1.34511
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.6913 - loss: 0.8900 - val_categorical_accuracy: 0.5800 - val_loss: 1.5191 - learning_rate: 0.0010
# Epoch 9/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7524 - loss: 0.6637
# Epoch 9: val_loss improved from 1.34511 to 1.02294, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00009-0.65307-0.73605-1.02294-0.67000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 188s 3s/step - categorical_accuracy: 0.7521 - loss: 0.6635 - val_categorical_accuracy: 0.6700 - val_loss: 1.0229 - learning_rate: 1.0000e-04
# Epoch 10/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7951 - loss: 0.5031
# Epoch 10: val_loss did not improve from 1.02294
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 191s 3s/step - categorical_accuracy: 0.7949 - loss: 0.5039 - val_categorical_accuracy: 0.5800 - val_loss: 1.4935 - learning_rate: 1.0000e-04
# Epoch 11/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7717 - loss: 0.5711
# Epoch 11: val_loss improved from 1.02294 to 0.94806, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00011-0.55361-0.78582-0.94806-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - categorical_accuracy: 0.7719 - loss: 0.5709 - val_categorical_accuracy: 0.6900 - val_loss: 0.9481 - learning_rate: 1.0000e-04
# Epoch 12/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7727 - loss: 0.5301
# Epoch 12: val_loss did not improve from 0.94806
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 189s 3s/step - categorical_accuracy: 0.7728 - loss: 0.5301 - val_categorical_accuracy: 0.7000 - val_loss: 0.9853 - learning_rate: 1.0000e-04
# Epoch 13/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.8483 - loss: 0.5052
# Epoch 13: val_loss improved from 0.94806 to 0.85003, saving model to model_conv3D_4_2024-04-0100_02_10.957255/model-00013-0.48631-0.84163-0.85003-0.75000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.8482 - loss: 0.5049 - val_categorical_accuracy: 0.7500 - val_loss: 0.8500 - learning_rate: 1.0000e-04
# Epoch 14/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7906 - loss: 0.5295
# Epoch 14: val_loss did not improve from 0.85003
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 186s 3s/step - categorical_accuracy: 0.7909 - loss: 0.5292 - val_categorical_accuracy: 0.7400 - val_loss: 0.9021 - learning_rate: 1.0000e-04
# Epoch 15/15
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.7774 - loss: 0.5760
# Epoch 15: val_loss did not improve from 0.85003
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 185s 3s/step - categorical_accuracy: 0.7778 - loss: 0.5750 - val_categorical_accuracy: 0.7200 - val_loss: 0.8890 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Model 5: Conv 3D Model with 30 frames per video (8, 16, 32, 64 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (8, 16, 32, 64) 
model = conv3D(conv_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 10
# # num_frames per video = 30
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_16 (Conv3D)              │ (None, 30, 120, 120,   │           656 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_28 (Activation)      │ (None, 30, 120, 120,   │             0 │
# │                                 │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 30, 120, 120,   │            32 │
# │ (BatchNormalization)            │ 8)                     │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_16 (MaxPooling3D) │ (None, 15, 60, 60, 8)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_17 (Conv3D)              │ (None, 15, 60, 60, 16) │         3,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_29 (Activation)      │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 15, 60, 60, 16) │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_17 (MaxPooling3D) │ (None, 7, 30, 30, 16)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_18 (Conv3D)              │ (None, 7, 30, 30, 32)  │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_30 (Activation)      │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 7, 30, 30, 32)  │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_18 (MaxPooling3D) │ (None, 3, 15, 15, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_19 (Conv3D)              │ (None, 3, 15, 15, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_31 (Activation)      │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 3, 15, 15, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_19 (MaxPooling3D) │ (None, 1, 7, 7, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 3136)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │       803,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_32 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_33 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_34 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 911,973 (3.48 MB)
#  Trainable params: 910,965 (3.48 MB)
#  Non-trainable params: 1,008 (3.94 KB)
# None

# %%
callbacks_list = model_callbacks("model_conv3D_5")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/25
# 64/67 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - categorical_accuracy: 0.3599 - loss: 1.7656
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.3636 - loss: 1.7571
# Epoch 1: val_loss improved from inf to 2.80142, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00001-1.57021-0.44344-2.80142-0.20000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - categorical_accuracy: 0.3648 - loss: 1.7543 - val_categorical_accuracy: 0.2000 - val_loss: 2.8014 - learning_rate: 0.0010
# Epoch 2/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.5911 - loss: 1.0551
# Epoch 2: val_loss improved from 2.80142 to 2.21969, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00002-1.05132-0.58824-2.21969-0.41000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 126s 2s/step - categorical_accuracy: 0.5911 - loss: 1.0551 - val_categorical_accuracy: 0.4100 - val_loss: 2.2197 - learning_rate: 0.0010
# Epoch 3/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.6900 - loss: 0.8085
# Epoch 3: val_loss did not improve from 2.21969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 123s 2s/step - categorical_accuracy: 0.6897 - loss: 0.8096 - val_categorical_accuracy: 0.3600 - val_loss: 2.5561 - learning_rate: 0.0010
# Epoch 4/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7199 - loss: 0.6995
# Epoch 4: val_loss did not improve from 2.21969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.7197 - loss: 0.7004 - val_categorical_accuracy: 0.3600 - val_loss: 2.6300 - learning_rate: 0.0010
# Epoch 5/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.7685 - loss: 0.5767
# Epoch 5: val_loss did not improve from 2.21969
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - categorical_accuracy: 0.7682 - loss: 0.5776 - val_categorical_accuracy: 0.4000 - val_loss: 2.4268 - learning_rate: 0.0010
# Epoch 6/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8306 - loss: 0.4803
# Epoch 6: val_loss improved from 2.21969 to 1.61787, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00006-0.46258-0.83861-1.61787-0.50000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.8308 - loss: 0.4801 - val_categorical_accuracy: 0.5000 - val_loss: 1.6179 - learning_rate: 1.0000e-04
# Epoch 7/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8095 - loss: 0.4843
# Epoch 7: val_loss improved from 1.61787 to 1.39935, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00007-0.45673-0.82956-1.39935-0.51000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.8097 - loss: 0.4839 - val_categorical_accuracy: 0.5100 - val_loss: 1.3994 - learning_rate: 1.0000e-04
# Epoch 8/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8510 - loss: 0.4146
# Epoch 8: val_loss improved from 1.39935 to 1.28201, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00008-0.43602-0.83710-1.28201-0.57000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.8508 - loss: 0.4149 - val_categorical_accuracy: 0.5700 - val_loss: 1.2820 - learning_rate: 1.0000e-04
# Epoch 9/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8881 - loss: 0.3462
# Epoch 9: val_loss improved from 1.28201 to 1.10940, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00009-0.37031-0.87330-1.10940-0.62000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.8879 - loss: 0.3466 - val_categorical_accuracy: 0.6200 - val_loss: 1.1094 - learning_rate: 1.0000e-04
# Epoch 10/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8947 - loss: 0.3404
# Epoch 10: val_loss improved from 1.10940 to 1.05932, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00010-0.33596-0.88839-1.05932-0.68000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.8946 - loss: 0.3403 - val_categorical_accuracy: 0.6800 - val_loss: 1.0593 - learning_rate: 1.0000e-04
# Epoch 11/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8917 - loss: 0.2826
# Epoch 11: val_loss improved from 1.05932 to 1.04154, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00011-0.27072-0.90347-1.04154-0.70000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.8919 - loss: 0.2824 - val_categorical_accuracy: 0.7000 - val_loss: 1.0415 - learning_rate: 1.0000e-04
# Epoch 12/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.8966 - loss: 0.2862
# Epoch 12: val_loss did not improve from 1.04154
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.8966 - loss: 0.2867 - val_categorical_accuracy: 0.6700 - val_loss: 1.0687 - learning_rate: 1.0000e-04
# Epoch 13/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9187 - loss: 0.2266
# Epoch 13: val_loss did not improve from 1.04154
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.9187 - loss: 0.2270 - val_categorical_accuracy: 0.7100 - val_loss: 1.0521 - learning_rate: 1.0000e-04
# Epoch 14/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9282 - loss: 0.2471
# Epoch 14: val_loss improved from 1.04154 to 0.97126, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00014-0.27728-0.92006-0.97126-0.69000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9280 - loss: 0.2475 - val_categorical_accuracy: 0.6900 - val_loss: 0.9713 - learning_rate: 1.0000e-04
# Epoch 15/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9188 - loss: 0.2492
# Epoch 15: val_loss improved from 0.97126 to 0.84969, saving model to model_conv3D_5_2024-04-0100_02_10.957255/model-00015-0.26555-0.91855-0.84969-0.73000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9188 - loss: 0.2495 - val_categorical_accuracy: 0.7300 - val_loss: 0.8497 - learning_rate: 1.0000e-04
# Epoch 16/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9294 - loss: 0.2580
# Epoch 16: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9291 - loss: 0.2583 - val_categorical_accuracy: 0.6800 - val_loss: 0.8973 - learning_rate: 1.0000e-04
# Epoch 17/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9343 - loss: 0.2029
# Epoch 17: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9343 - loss: 0.2028 - val_categorical_accuracy: 0.7000 - val_loss: 0.9266 - learning_rate: 1.0000e-04
# Epoch 18/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9474 - loss: 0.1890
# Epoch 18: val_loss did not improve from 0.84969
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9472 - loss: 0.1891 - val_categorical_accuracy: 0.6900 - val_loss: 0.8868 - learning_rate: 1.0000e-04
# Epoch 19/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9572 - loss: 0.1500
# Epoch 19: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9570 - loss: 0.1504 - val_categorical_accuracy: 0.7000 - val_loss: 0.9247 - learning_rate: 1.0000e-04
# Epoch 20/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9607 - loss: 0.1590
# Epoch 20: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9606 - loss: 0.1594 - val_categorical_accuracy: 0.6500 - val_loss: 1.0372 - learning_rate: 1.0000e-04
# Epoch 21/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9641 - loss: 0.1394
# Epoch 21: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 118s 2s/step - categorical_accuracy: 0.9642 - loss: 0.1394 - val_categorical_accuracy: 0.6800 - val_loss: 1.0411 - learning_rate: 1.0000e-04
# Epoch 22/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9561 - loss: 0.1602
# Epoch 22: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 116s 2s/step - categorical_accuracy: 0.9561 - loss: 0.1600 - val_categorical_accuracy: 0.6800 - val_loss: 1.0485 - learning_rate: 1.0000e-04
# Epoch 23/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9396 - loss: 0.2063
# Epoch 23: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9398 - loss: 0.2059 - val_categorical_accuracy: 0.6900 - val_loss: 1.0406 - learning_rate: 1.0000e-04
# Epoch 24/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9506 - loss: 0.1529
# Epoch 24: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9506 - loss: 0.1535 - val_categorical_accuracy: 0.6900 - val_loss: 0.9773 - learning_rate: 1.0000e-04
# Epoch 25/25
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - categorical_accuracy: 0.9603 - loss: 0.1391
# Epoch 25: val_loss did not improve from 0.84969
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 117s 2s/step - categorical_accuracy: 0.9603 - loss: 0.1393 - val_categorical_accuracy: 0.7000 - val_loss: 0.9905 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Model 6: Conv 3D Model with 20 frames per video (32, 64, 128, 256) filters conv 3D layers + 128 dense layer + 128 dense layer + image size 120 by 120)

# %%
num_epochs = 25 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 20  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num_frames per video =', num_frames)
height = 120
width = 120

conv_filters = (32, 64, 128, 256)
dense_filters = (128, 128)
model = conv3D(conv_filters=conv_filters,dense_nodes=dense_filters, num_images=num_frames)
print (model.summary())
# Out:
# # epochs = 25
# # batch size = 20
# # num_frames per video = 20
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_20 (Conv3D)              │ (None, 20, 120, 120,   │         2,624 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_35 (Activation)      │ (None, 20, 120, 120,   │             0 │
# │                                 │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 20, 120, 120,   │           128 │
# │ (BatchNormalization)            │ 32)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_20 (MaxPooling3D) │ (None, 10, 60, 60, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_21 (Conv3D)              │ (None, 10, 60, 60, 64) │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_36 (Activation)      │ (None, 10, 60, 60, 64) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 10, 60, 60, 64) │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_21 (MaxPooling3D) │ (None, 5, 30, 30, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_22 (Conv3D)              │ (None, 5, 30, 30, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_37 (Activation)      │ (None, 5, 30, 30, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 5, 30, 30, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_22 (MaxPooling3D) │ (None, 2, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_23 (Conv3D)              │ (None, 2, 15, 15, 256) │       884,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_38 (Activation)      │ (None, 2, 15, 15, 256) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 2, 15, 15, 256) │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_23 (MaxPooling3D) │ (None, 1, 7, 7, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 12544)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 128)            │     1,605,760 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_39 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_40 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_41 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,790,149 (10.64 MB)
#  Trainable params: 2,788,677 (10.64 MB)
#  Non-trainable params: 1,472 (5.75 KB)
# None

# %%
callbacks_list = model_callbacks("model_conv3D_6")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=False, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/25
# 32/34 ━━━━━━━━━━━━━━━━━━━━ 16s 8s/step - categorical_accuracy: 0.4028 - loss: 1.6642
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.4065 - loss: 1.6520
# Epoch 1: val_loss improved from inf to 10.63336, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00001-1.45300-0.46456-10.63336-0.24000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 288s 8s/step - categorical_accuracy: 0.4081 - loss: 1.6463 - val_categorical_accuracy: 0.2400 - val_loss: 10.6334 - learning_rate: 0.0010
# Epoch 2/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5782 - loss: 1.1294
# Epoch 2: val_loss improved from 10.63336 to 1.47409, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00002-1.09941-0.57919-1.47409-0.40000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 276s 8s/step - categorical_accuracy: 0.5782 - loss: 1.1285 - val_categorical_accuracy: 0.4000 - val_loss: 1.4741 - learning_rate: 0.0010
# Epoch 3/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.5891 - loss: 1.0567
# Epoch 3: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 272s 8s/step - categorical_accuracy: 0.5904 - loss: 1.0531 - val_categorical_accuracy: 0.2200 - val_loss: 2.9526 - learning_rate: 0.0010
# Epoch 4/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7511 - loss: 0.7339
# Epoch 4: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 272s 8s/step - categorical_accuracy: 0.7504 - loss: 0.7354 - val_categorical_accuracy: 0.2800 - val_loss: 1.8563 - learning_rate: 0.0010
# Epoch 5/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.6976 - loss: 0.7735
# Epoch 5: val_loss did not improve from 1.47409
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 269s 8s/step - categorical_accuracy: 0.6970 - loss: 0.7752 - val_categorical_accuracy: 0.3400 - val_loss: 2.6187 - learning_rate: 0.0010
# Epoch 6/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7493 - loss: 0.6899
# Epoch 6: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 270s 8s/step - categorical_accuracy: 0.7495 - loss: 0.6903 - val_categorical_accuracy: 0.3300 - val_loss: 2.4644 - learning_rate: 1.0000e-04
# Epoch 7/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7681 - loss: 0.6556
# Epoch 7: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 272s 8s/step - categorical_accuracy: 0.7679 - loss: 0.6552 - val_categorical_accuracy: 0.3500 - val_loss: 2.3173 - learning_rate: 1.0000e-04
# Epoch 8/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7895 - loss: 0.5692
# Epoch 8: val_loss did not improve from 1.47409
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0001.
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 272s 8s/step - categorical_accuracy: 0.7896 - loss: 0.5690 - val_categorical_accuracy: 0.3800 - val_loss: 2.2355 - learning_rate: 1.0000e-04
# Epoch 9/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7939 - loss: 0.5558
# Epoch 9: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 273s 8s/step - categorical_accuracy: 0.7935 - loss: 0.5573 - val_categorical_accuracy: 0.4000 - val_loss: 2.0542 - learning_rate: 1.0000e-04
# Epoch 10/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7979 - loss: 0.5271
# Epoch 10: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 271s 8s/step - categorical_accuracy: 0.7987 - loss: 0.5261 - val_categorical_accuracy: 0.4500 - val_loss: 1.9808 - learning_rate: 1.0000e-04
# Epoch 11/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8203 - loss: 0.5293
# Epoch 11: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 272s 8s/step - categorical_accuracy: 0.8198 - loss: 0.5289 - val_categorical_accuracy: 0.4300 - val_loss: 1.8688 - learning_rate: 1.0000e-04
# Epoch 12/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.7950 - loss: 0.5157
# Epoch 12: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 271s 8s/step - categorical_accuracy: 0.7952 - loss: 0.5151 - val_categorical_accuracy: 0.4500 - val_loss: 1.6387 - learning_rate: 1.0000e-04
# Epoch 13/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8513 - loss: 0.4174
# Epoch 13: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 269s 8s/step - categorical_accuracy: 0.8508 - loss: 0.4183 - val_categorical_accuracy: 0.4600 - val_loss: 1.5940 - learning_rate: 1.0000e-04
# Epoch 14/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8716 - loss: 0.3788
# Epoch 14: val_loss did not improve from 1.47409
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 270s 8s/step - categorical_accuracy: 0.8712 - loss: 0.3800 - val_categorical_accuracy: 0.4600 - val_loss: 1.5235 - learning_rate: 1.0000e-04
# Epoch 15/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8583 - loss: 0.4467
# Epoch 15: val_loss improved from 1.47409 to 1.38199, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00015-0.45304-0.85370-1.38199-0.50000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 273s 8s/step - categorical_accuracy: 0.8582 - loss: 0.4469 - val_categorical_accuracy: 0.5000 - val_loss: 1.3820 - learning_rate: 1.0000e-04
# Epoch 16/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8654 - loss: 0.3782
# Epoch 16: val_loss improved from 1.38199 to 1.20654, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00016-0.37981-0.85822-1.20654-0.54000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 270s 8s/step - categorical_accuracy: 0.8652 - loss: 0.3783 - val_categorical_accuracy: 0.5400 - val_loss: 1.2065 - learning_rate: 1.0000e-04
# Epoch 17/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8772 - loss: 0.3400
# Epoch 17: val_loss improved from 1.20654 to 1.11679, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00017-0.36802-0.87783-1.11679-0.56000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 271s 8s/step - categorical_accuracy: 0.8772 - loss: 0.3408 - val_categorical_accuracy: 0.5600 - val_loss: 1.1168 - learning_rate: 1.0000e-04
# Epoch 18/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.8978 - loss: 0.3128
# Epoch 18: val_loss improved from 1.11679 to 1.09313, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00018-0.30944-0.90045-1.09313-0.56000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 267s 8s/step - categorical_accuracy: 0.8979 - loss: 0.3127 - val_categorical_accuracy: 0.5600 - val_loss: 1.0931 - learning_rate: 1.0000e-04
# Epoch 19/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9017 - loss: 0.2781
# Epoch 19: val_loss improved from 1.09313 to 1.01774, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00019-0.29653-0.90347-1.01774-0.65000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 271s 8s/step - categorical_accuracy: 0.9017 - loss: 0.2786 - val_categorical_accuracy: 0.6500 - val_loss: 1.0177 - learning_rate: 1.0000e-04
# Epoch 20/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9028 - loss: 0.2970
# Epoch 20: val_loss improved from 1.01774 to 0.87143, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00020-0.33196-0.89140-0.87143-0.65000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 271s 8s/step - categorical_accuracy: 0.9024 - loss: 0.2980 - val_categorical_accuracy: 0.6500 - val_loss: 0.8714 - learning_rate: 1.0000e-04
# Epoch 21/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9046 - loss: 0.2892
# Epoch 21: val_loss improved from 0.87143 to 0.77889, saving model to model_conv3D_6_2024-04-0100_02_10.957255/model-00021-0.32055-0.89291-0.77889-0.67000.keras
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 269s 8s/step - categorical_accuracy: 0.9043 - loss: 0.2901 - val_categorical_accuracy: 0.6700 - val_loss: 0.7789 - learning_rate: 1.0000e-04
# Epoch 22/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9100 - loss: 0.3242
# Epoch 22: val_loss did not improve from 0.77889
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 270s 8s/step - categorical_accuracy: 0.9100 - loss: 0.3242 - val_categorical_accuracy: 0.6800 - val_loss: 0.8289 - learning_rate: 1.0000e-04
# Epoch 23/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9330 - loss: 0.2446
# Epoch 23: val_loss did not improve from 0.77889
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 269s 8s/step - categorical_accuracy: 0.9326 - loss: 0.2462 - val_categorical_accuracy: 0.6700 - val_loss: 0.7867 - learning_rate: 1.0000e-04
# Epoch 24/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9138 - loss: 0.2617
# Epoch 24: val_loss did not improve from 0.77889
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 270s 8s/step - categorical_accuracy: 0.9137 - loss: 0.2622 - val_categorical_accuracy: 0.7100 - val_loss: 0.8089 - learning_rate: 1.0000e-04
# Epoch 25/25
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 8s/step - categorical_accuracy: 0.9387 - loss: 0.2183
# Epoch 25: val_loss did not improve from 0.77889
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 269s 8s/step - categorical_accuracy: 0.9382 - loss: 0.2197 - val_categorical_accuracy: 0.6900 - val_loss: 0.7801 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Model 7: Conv 3D Model with 30 frames per video and a 5 by 5 filter size (16, 32, 64, 128 filters conv 3D layers + 256 dense layer + 128 dense layer + image size 120 by 120)

# %%
#write your model here
def conv3D_5by5(conv_filters=(16, 32, 64, 128), dense_nodes=(256,128), dropout=0.25, num_images=20, height=120, width=120):

    model = Sequential()

    model.add(Conv3D(conv_filters[0], (5, 5, 5), padding='same', input_shape=(num_images, height, width, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Conv3D(conv_filters[1], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[2], (3, 3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(conv_filters[3], (3, 3, 3), padding='same'))    
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Flatten())
    model.add(Dense(dense_nodes[0]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(dense_nodes[1]))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(dropout))

    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    
    return model

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 5  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num_frames per video =', num_frames)
height = 120
width = 120

model = conv3D_5by5(num_images=num_frames)

print (model.summary())
# Out:
# # epochs = 15
# # batch size = 5
# # num_frames per video = 30
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv3d_24 (Conv3D)              │ (None, 30, 120, 120,   │         6,016 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_42 (Activation)      │ (None, 30, 120, 120,   │             0 │
# │                                 │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 30, 120, 120,   │            64 │
# │ (BatchNormalization)            │ 16)                    │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_24 (MaxPooling3D) │ (None, 15, 60, 60, 16) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_25 (Conv3D)              │ (None, 15, 60, 60, 32) │        13,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_43 (Activation)      │ (None, 15, 60, 60, 32) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 15, 60, 60, 32) │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_25 (MaxPooling3D) │ (None, 7, 30, 30, 32)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_26 (Conv3D)              │ (None, 7, 30, 30, 64)  │        55,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_44 (Activation)      │ (None, 7, 30, 30, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 7, 30, 30, 64)  │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_26 (MaxPooling3D) │ (None, 3, 15, 15, 64)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv3d_27 (Conv3D)              │ (None, 3, 15, 15, 128) │       221,312 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_45 (Activation)      │ (None, 3, 15, 15, 128) │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 3, 15, 15, 128) │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling3d_27 (MaxPooling3D) │ (None, 1, 7, 7, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 256)            │     1,605,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_46 (Activation)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_47 (Activation)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 5)              │           645 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_48 (Activation)      │ (None, 5)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,938,469 (7.39 MB)
#  Trainable params: 1,937,221 (7.39 MB)
#  Non-trainable params: 1,248 (4.88 KB)
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_conv3D_9")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15
# 131/133 ━━━━━━━━━━━━━━━━━━━━ 5s 3s/step - categorical_accuracy: 0.3830 - loss: 1.8661
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3833 - loss: 1.8637
# Epoch 1: val_loss improved from inf to 7.93461, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00001-1.70849-0.39668-7.93461-0.29000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 379s 3s/step - categorical_accuracy: 0.3834 - loss: 1.8626 - val_categorical_accuracy: 0.2900 - val_loss: 7.9346 - learning_rate: 0.0010
# Epoch 2/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.3635 - loss: 1.6067
# Epoch 2: val_loss improved from 7.93461 to 1.85424, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00002-1.66025-0.37858-1.85424-0.39000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - categorical_accuracy: 0.3636 - loss: 1.6071 - val_categorical_accuracy: 0.3900 - val_loss: 1.8542 - learning_rate: 0.0010
# Epoch 3/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4245 - loss: 1.4947
# Epoch 3: val_loss improved from 1.85424 to 1.46734, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00003-1.46971-0.41176-1.46734-0.44000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 368s 3s/step - categorical_accuracy: 0.4244 - loss: 1.4945 - val_categorical_accuracy: 0.4400 - val_loss: 1.4673 - learning_rate: 0.0010
# Epoch 4/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4056 - loss: 1.4965
# Epoch 4: val_loss did not improve from 1.46734
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - categorical_accuracy: 0.4059 - loss: 1.4959 - val_categorical_accuracy: 0.3800 - val_loss: 2.1963 - learning_rate: 0.0010
# Epoch 5/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5269 - loss: 1.3002
# Epoch 5: val_loss did not improve from 1.46734
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - categorical_accuracy: 0.5266 - loss: 1.3005 - val_categorical_accuracy: 0.4400 - val_loss: 2.6110 - learning_rate: 0.0010
# Epoch 6/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4342 - loss: 1.3603
# Epoch 6: val_loss improved from 1.46734 to 1.31821, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00006-1.35887-0.46003-1.31821-0.55000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 363s 3s/step - categorical_accuracy: 0.4344 - loss: 1.3602 - val_categorical_accuracy: 0.5500 - val_loss: 1.3182 - learning_rate: 0.0010
# Epoch 7/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.4623 - loss: 1.3274
# Epoch 7: val_loss did not improve from 1.31821
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 364s 3s/step - categorical_accuracy: 0.4625 - loss: 1.3270 - val_categorical_accuracy: 0.4600 - val_loss: 1.5920 - learning_rate: 0.0010
# Epoch 8/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5553 - loss: 1.1674
# Epoch 8: val_loss did not improve from 1.31821
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - categorical_accuracy: 0.5552 - loss: 1.1674 - val_categorical_accuracy: 0.5000 - val_loss: 1.7506 - learning_rate: 0.0010
# Epoch 9/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5352 - loss: 1.1672
# Epoch 9: val_loss improved from 1.31821 to 1.14446, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00009-1.15604-0.55354-1.14446-0.58000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - categorical_accuracy: 0.5354 - loss: 1.1671 - val_categorical_accuracy: 0.5800 - val_loss: 1.1445 - learning_rate: 0.0010
# Epoch 10/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5758 - loss: 1.0624
# Epoch 10: val_loss improved from 1.14446 to 0.91354, saving model to model_conv3D_9_2024-04-0100_02_10.957255/model-00010-1.07023-0.56561-0.91354-0.65000.keras
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - categorical_accuracy: 0.5757 - loss: 1.0624 - val_categorical_accuracy: 0.6500 - val_loss: 0.9135 - learning_rate: 0.0010
# Epoch 11/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6014 - loss: 1.0108
# Epoch 11: val_loss did not improve from 0.91354
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - categorical_accuracy: 0.6012 - loss: 1.0110 - val_categorical_accuracy: 0.2800 - val_loss: 3.3639 - learning_rate: 0.0010
# Epoch 12/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6279 - loss: 0.9616
# Epoch 12: val_loss did not improve from 0.91354
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - categorical_accuracy: 0.6276 - loss: 0.9623 - val_categorical_accuracy: 0.5200 - val_loss: 1.2905 - learning_rate: 0.0010
# Epoch 13/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6166 - loss: 0.9641
# Epoch 13: val_loss did not improve from 0.91354
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - categorical_accuracy: 0.6165 - loss: 0.9643 - val_categorical_accuracy: 0.5700 - val_loss: 1.2197 - learning_rate: 0.0010
# Epoch 14/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.5956 - loss: 0.9742
# Epoch 14: val_loss did not improve from 0.91354
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - categorical_accuracy: 0.5958 - loss: 0.9738 - val_categorical_accuracy: 0.5600 - val_loss: 1.1077 - learning_rate: 1.0000e-04
# Epoch 15/15
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - categorical_accuracy: 0.6287 - loss: 0.9045
# Epoch 15: val_loss did not improve from 0.91354
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 365s 3s/step - categorical_accuracy: 0.6287 - loss: 0.9045 - val_categorical_accuracy: 0.5600 - val_loss: 1.1003 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# ### TRANSFER LEARNING - MobileNet Conv2d + GRU

# %%
from keras.applications import mobilenet

def mobilenet_RNN(fine_tune=False, gru=False, lstm_gru_cells=128, dense_nodes=128, dropout=0.25, num_images=20, height=120, width=120):

    mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
    print("Number of layers in the pretrained mobilenet model: ", len(mobilenet_transfer.layers))

    if (fine_tune):
        # Fine-tune from this layer onwards
        fine_tune_at = 50
        # Freeze all the layers before the `fine_tune_at` layer
        for layer in mobilenet_transfer.layers[:fine_tune_at]:
            layer.trainable = False

    model = Sequential()
    model.add(TimeDistributed(mobilenet_transfer,input_shape=(num_images, height, width, 3)))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Flatten()))
    if (gru):
        model.add(GRU(lstm_gru_cells))
    else:
        model.add(LSTM(lstm_gru_cells))
    model.add(Dropout(dropout))
    model.add(Dense(dense_nodes, activation='relu'))
    model.add(Dropout(dropout))
    model.add(Dense(num_classes, activation='softmax'))

    opt = tf.keras.optimizers.Adam() #write your optimizer
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])    
    return model

# %% [markdown]
# #### Model 8: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes

# %%
num_epochs = 20 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(num_images=num_frames, gru=True)
print (model.summary())
# Out:
# # epochs = 20
# # batch size = 10
# # num frames per video = 20
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2976428483.py:5: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Number of layers in the pretrained mobilenet model:  86
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ ?                      │     3,228,864 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,864 (12.32 MB)
#  Trainable params: 3,206,976 (12.23 MB)
#  Non-trainable params: 21,888 (85.50 KB)
# None

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/20
# 65/67 ━━━━━━━━━━━━━━━━━━━━ 14s 7s/step - categorical_accuracy: 0.2441 - loss: 1.7634
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_40322/2963303598.py:76: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - categorical_accuracy: 0.2443 - loss: 1.7615
# Epoch 1: val_loss improved from inf to 1.60953, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00001-1.69930-0.25038-1.60953-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1058s 12s/step - categorical_accuracy: 0.2444 - loss: 1.7606 - val_categorical_accuracy: 0.1800 - val_loss: 1.6095 - learning_rate: 0.0010
# Epoch 2/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1884 - loss: 1.6096
# Epoch 2: val_loss improved from 1.60953 to 1.60912, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00002-1.60956-0.20513-1.60912-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 371s 5s/step - categorical_accuracy: 0.1887 - loss: 1.6096 - val_categorical_accuracy: 0.1800 - val_loss: 1.6091 - learning_rate: 0.0010
# Epoch 3/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1950 - loss: 1.6086
# Epoch 3: val_loss improved from 1.60912 to 1.60900, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00003-1.60935-0.20513-1.60900-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 356s 5s/step - categorical_accuracy: 0.1951 - loss: 1.6087 - val_categorical_accuracy: 0.1800 - val_loss: 1.6090 - learning_rate: 0.0010
# Epoch 4/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2038 - loss: 1.6089
# Epoch 4: val_loss improved from 1.60900 to 1.60895, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00004-1.60919-0.19155-1.60895-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 362s 5s/step - categorical_accuracy: 0.2036 - loss: 1.6089 - val_categorical_accuracy: 0.1800 - val_loss: 1.6089 - learning_rate: 0.0010
# Epoch 5/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2027 - loss: 1.6090
# Epoch 5: val_loss improved from 1.60895 to 1.60874, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00005-1.60910-0.20513-1.60874-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 358s 5s/step - categorical_accuracy: 0.2027 - loss: 1.6090 - val_categorical_accuracy: 0.1800 - val_loss: 1.6087 - learning_rate: 0.0010
# Epoch 6/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1794 - loss: 1.6095
# Epoch 6: val_loss improved from 1.60874 to 1.60830, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00006-1.60914-0.18552-1.60830-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 358s 5s/step - categorical_accuracy: 0.1795 - loss: 1.6095 - val_categorical_accuracy: 0.1800 - val_loss: 1.6083 - learning_rate: 0.0010
# Epoch 7/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2120 - loss: 1.6083
# Epoch 7: val_loss did not improve from 1.60830
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 346s 5s/step - categorical_accuracy: 0.2119 - loss: 1.6083 - val_categorical_accuracy: 0.1800 - val_loss: 1.6084 - learning_rate: 0.0010
# Epoch 8/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2120 - loss: 1.6084
# Epoch 8: val_loss improved from 1.60830 to 1.60805, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00008-1.60904-0.20513-1.60805-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 342s 5s/step - categorical_accuracy: 0.2119 - loss: 1.6084 - val_categorical_accuracy: 0.1800 - val_loss: 1.6080 - learning_rate: 0.0010
# Epoch 9/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1873 - loss: 1.6089
# Epoch 9: val_loss improved from 1.60805 to 1.60778, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00009-1.60882-0.19608-1.60778-0.18000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 340s 5s/step - categorical_accuracy: 0.1874 - loss: 1.6089 - val_categorical_accuracy: 0.1800 - val_loss: 1.6078 - learning_rate: 0.0010
# Epoch 10/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2227 - loss: 1.6098
# Epoch 10: val_loss improved from 1.60778 to 1.60766, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00010-1.60932-0.20664-1.60766-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 340s 5s/step - categorical_accuracy: 0.2224 - loss: 1.6098 - val_categorical_accuracy: 0.2100 - val_loss: 1.6077 - learning_rate: 0.0010
# Epoch 11/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2301 - loss: 1.6084
# Epoch 11: val_loss improved from 1.60766 to 1.60760, saving model to model_retrain_mobilenet_gru_2024-04-0100_02_10.957255/model-00011-1.60916-0.20664-1.60760-0.21000.keras
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 356s 5s/step - categorical_accuracy: 0.2298 - loss: 1.6084 - val_categorical_accuracy: 0.2100 - val_loss: 1.6076 - learning_rate: 0.0010
# Epoch 12/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1750 - loss: 1.6100
# Epoch 12: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 364s 5s/step - categorical_accuracy: 0.1750 - loss: 1.6100 - val_categorical_accuracy: 0.2100 - val_loss: 1.6077 - learning_rate: 0.0010
# Epoch 13/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1938 - loss: 1.6096
# Epoch 13: val_loss did not improve from 1.60760
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 363s 5s/step - categorical_accuracy: 0.1937 - loss: 1.6095 - val_categorical_accuracy: 0.1800 - val_loss: 1.6077 - learning_rate: 0.0010
# Epoch 14/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2122 - loss: 1.6089
# Epoch 14: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 364s 5s/step - categorical_accuracy: 0.2121 - loss: 1.6089 - val_categorical_accuracy: 0.1800 - val_loss: 1.6077 - learning_rate: 1.0000e-04
# Epoch 15/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2181 - loss: 1.6072
# Epoch 15: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 360s 5s/step - categorical_accuracy: 0.2179 - loss: 1.6072 - val_categorical_accuracy: 0.1800 - val_loss: 1.6077 - learning_rate: 1.0000e-04
# Epoch 16/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1936 - loss: 1.6084
# Epoch 16: val_loss did not improve from 1.60760
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001.
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 374s 6s/step - categorical_accuracy: 0.1937 - loss: 1.6084 - val_categorical_accuracy: 0.1800 - val_loss: 1.6077 - learning_rate: 1.0000e-04
# Epoch 17/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1922 - loss: 1.6091
# Epoch 17: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 359s 5s/step - categorical_accuracy: 0.1924 - loss: 1.6091 - val_categorical_accuracy: 0.1800 - val_loss: 1.6077 - learning_rate: 1.0000e-04
# Epoch 18/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.1892 - loss: 1.6086
# Epoch 18: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 362s 5s/step - categorical_accuracy: 0.1894 - loss: 1.6086 - val_categorical_accuracy: 0.1800 - val_loss: 1.6076 - learning_rate: 1.0000e-04
# Epoch 19/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2006 - loss: 1.6093
# Epoch 19: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 373s 6s/step - categorical_accuracy: 0.2007 - loss: 1.6093 - val_categorical_accuracy: 0.1800 - val_loss: 1.6076 - learning_rate: 1.0000e-04
# Epoch 20/20
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - categorical_accuracy: 0.2220 - loss: 1.6074
# Epoch 20: val_loss did not improve from 1.60760
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 374s 6s/step - categorical_accuracy: 0.2218 - loss: 1.6074 - val_categorical_accuracy: 0.1800 - val_loss: 1.6076 - learning_rate: 1.0000e-04

# %%
plot_loss_accuracy(history)
# Out:
# dict_keys(['categorical_accuracy', 'loss', 'val_categorical_accuracy', 'val_loss', 'learning_rate'])

# %% [markdown]
# #### Model 9: Mobilenet (re train all weights) + GRU (128 cells) + 128 dense nodes + Random data transformations on training data set

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 30
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(gru=True, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num frames per video = 30
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2976428483.py:5: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
# 2024-04-01 20:30:56.641201: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3 Pro
# 2024-04-01 20:30:56.641280: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 18.00 GB
# 2024-04-01 20:30:56.641299: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 6.00 GB
# 2024-04-01 20:30:56.641360: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-04-01 20:30:56.641401: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Number of layers in the pretrained mobilenet model:  86
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ ?                      │     3,228,864 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,864 (12.32 MB)
#  Trainable params: 3,206,976 (12.23 MB)
#  Non-trainable params: 21,888 (85.50 KB)
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_gru")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, augment=True, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15
# 2024-04-01 20:31:45.555620: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
#  5/67 ━━━━━━━━━━━━━━━━━━━━ 1:14:46 72s/step - categorical_accuracy: 0.1930 - loss: 1.9380
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1,
#       2                               callbacks=callbacks_list, validation_data=val_generator,
#       3                               validation_steps=validation_steps, class_weight=None, initial_epoch=0)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:325, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     323 for step, iterator in epoch_iterator.enumerate_epoch():
#     324     callbacks.on_train_batch_begin(step)
# --> 325     logs = self.train_function(iterator)
#     326     callbacks.on_train_batch_end(
#     327         step, self._pythonify_logs(logs)
#     328     )
#     329     if self.stop_training:
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File /opt/anaconda3/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
plot_loss_accuracy(history)

# %% [markdown]
# #### Model 10: Mobilenet (re train all wieghts) + LSTM (128 cells) + 128 dense nodes

# %%
num_epochs = 15 # choose the number of epochs
print ('# epochs =', num_epochs)
batch_size = 10  #experiment with the batch size
print ('# batch size =', batch_size)
num_frames = 20
print ('# num frames per video =', num_frames)
height = 120
width = 120

model = mobilenet_RNN(fine_tune=False, gru=False, num_images=num_frames)
print(model.summary())
# Out:
# # epochs = 15
# # batch size = 10
# # num frames per video = 20
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2976428483.py:5: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)
# Number of layers in the pretrained mobilenet model:  86
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed_4              │ ?                      │     3,228,864 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_5              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_6              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_7              │ ?                      │   0 (unbuilt) │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,228,864 (12.32 MB)
#  Trainable params: 3,206,976 (12.23 MB)
#  Non-trainable params: 21,888 (85.50 KB)
# None

# %%
callbacks_list = model_callbacks("model_retrain_mobilenet_lstm")

steps_per_epoch, validation_steps = calculate_steps(num_train_sequences, num_val_sequences, batch_size)

train_generator = generate(train_path, train_doc, batch_size, num_images=num_frames)

val_generator   = generate(val_path, val_doc, batch_size, num_images=num_frames)

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                              callbacks=callbacks_list, validation_data=val_generator, 
                              validation_steps=validation_steps, class_weight=None, initial_epoch=0)
# Out:
# /var/folders/tj/qvp4flyj0tv1c0sjc_mhf8_c0000gn/T/ipykernel_62502/2963303598.py:47: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
# Epoch 1/15

# %%
plot_loss_accuracy(history)
